# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isna().sum() # 데이터 컬럼별 결측치 확인
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df_copy['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df_copy = df.copy()
cond = df_copy['survived'] == 1
df_copy.loc[cond, 'embarked'].value_counts()
# Out:
# embarked
# S    217
# C     93
# Q     30
# Name: count, dtype: int64

# %%
df_copy.groupby(['embarked'])['survived'].mean()
# Out:
# embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: survived, dtype: float64

# %%
df_copy.groupby(['embarked'])[['survived']].agg(['sum', 'mean'])
# Out:
#          survived
#               sum      mean
# embarked
# C              93  0.553571
# Q              30  0.389610
# S             217  0.336957

# %%
df_copy.groupby(['sex'])[['survived']].agg(['sum', 'mean'])
# Out:
#        survived
#             sum      mean
# sex
# female      233  0.742038
# male        109  0.188908

# %%
df_copy.groupby(['alone'])[['survived']].agg(['sum', 'mean'])
# Out:
#       survived
#            sum      mean
# alone
# False      179  0.505650
# True       163  0.303538

# %%
df_copy.pivot_table(index='sex', columns= 'pclass', values = 'survived', aggfunc = ['sum', 'mean'])
# Out:
#        sum              mean
# pclass   1   2   3         1         2         3
# sex
# female  91  70  72  0.968085  0.921053  0.500000
# male    45  17  47  0.368852  0.157407  0.135447

# %%
df_copy.groupby(['alone', 'sex'])[['survived']].agg(['sum', 'mean'])
# Out:
#              survived
#                   sum      mean
# alone sex
# False female      134  0.712766
#       male         45  0.271084
# True  female       99  0.785714
#       male         64  0.155718

# %%
group1 = df_copy.groupby(['who', 'pclass'])[['survived']].agg(['sum', 'mean'])
group1 = group1.droplevel(level=0, axis=1)
group1.sort_values('mean', ascending=False).reset_index()
# Out:
#      who  pclass  sum      mean
# 0  child       2   19  1.000000
# 1  woman       1   89  0.978022
# 2  woman       2   60  0.909091
# 3  child       1    5  0.833333
# 4  woman       3   56  0.491228
# 5  child       3   25  0.431034
# 6    man       1   42  0.352941
# 7    man       3   38  0.119122
# 8    man       2    8  0.080808
